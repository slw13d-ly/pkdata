# %%
# 클래스

# %%
# 불편한 코드
result1 = 0
result2 = 0

def add1(num):
    global result1
    result1 += num
    return result1 

def add2(num):
    global result2
    result2 += num
    return result2

print(add1(3))
print(add2(4))
# Out:
# 3
# 4

# %%
# 클래스 사용

class Cal: # 함수와의 차이 
    def add(num)
