# %% [markdown]
# # 코드 응용

# %%
# 응용 # 웹 크롤링
import requests as req
from bs4 import BeautifulSoup as bs
url = "https://www.melon.com/chart/index.htm"
headers = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/145.0.0.0 Safari/537.36 Edg/145.0.0.0'}
web = req.get(url , headers=headers)
web.content
soup = bs(web.content, 'html.parser') # 정리

title = soup.select('.rank01')[:20]
name = soup.select('.checkEllipsis a')[:20]

str = ''
for i, (t, n) in enumerate(zip(title, name),1):
    str += f'{i}위: {t.text.strip()} / {n.text}\n' 
print(str,end=' ')
# Out:
# 1위: BANG BANG / IVE (아이브)
# 2위: 404 (New Era) / KiiiKiii (키키)
# 3위: Good Goodbye / 화사 (HWASA)
# 4위: 그대 작은 나의 세상이 되어 / 카더가든
# 5위: 사랑하게 될 거야 / 한로로
# 6위: Drowning / WOODZ
# 7위: 타임캡슐 / 다비치
# 8위: 0+0 / 한로로
# 9위: Blue Valentine / NMIXX
# 10위: Golden / HUNTR/X
# 11위: 멸종위기사랑 / EJAE
# 12위: ONE MORE TIME / AUDREY NUNA
# 13위: 어제보다 슬픈 오늘 / REI AMI
# 14위: SPAGHETTI (feat. j-hope of BTS) / KPop Demon Hunters Cast
# 15위: 뛰어(JUMP) / 이찬혁
# 16위: BLACKHOLE / ALLDAY PROJECT
# 17위: NOT CUTE ANYMORE / 우디 (Woody)
# 18위: RUDE! / LE SSERAFIM (르세라핌)
# 19위: toxic till the end / j-hope
# 20위: 모르시나요(PROD.로코베리) / BLACKPINK

# %%
import requests as req
from bs4 import BeautifulSoup as bs
url = "https://www.pusan.ac.kr/kor/CMS/MenuMgr/menuListOnBuilding.do?mCode=MN202"
headers = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/145.0.0.0 Safari/537.36 Edg/145.0.0.0'}
web = req.get(url , headers=headers)
web.content
soup = bs(web.content, 'html.parser')

menulist = soup.select(".menu-tbl")
day = soup.select(".day")
date = soup.select(".date")
won = soup.select(".menu-tit01")
menu = soup.select(".menu-tit01 + p") # 형제(옆에 있는) p 호출
 
for e, y, m in zip(date, day, menu):
    print("="*15)
    print(e.text.strip(), y.text.strip())
    print("-"*15)
    print(m.text.replace('\r', '\n')) # menu[0].text.replace('\r', '\n')
# 가격, 매뉴 꺼내기
# Out:
# ===============
# 2026.02.23 월
# ---------------
# 백미밥
# 반계탕
# 탕수육/레몬소스
# 사각어묵오징어무침
# 잔멸치건새우견과류볶음
# 다시마무채무침
# 포기김치
#
# ===============
# 2026.02.24 화
# ---------------
# 녹차밥
# 수제비국
# 돈육김치볶음
# 새우가스/케찹
# 푸실리과일샐러드
# 상추겉절이
# 석박지
#
# ===============
# 2026.02.25 수
# ---------------
# 백미밥
# 짬뽕국
# 떡갈비/파채소스
# 스파게티/로제소스
# 어묵버섯조림
# 치커리유자청무침
# 배추김치
#
# ===============
# 2026.02.26 목
# ---------------
# 흑미밥
# 어묵국
# 치킨치즈가스/머스터드
# 쇠고기하이라이스
# 순대볶음
# 해초무초무침
# 배추김치
#
# ===============
# 2026.02.27 금
# ---------------
# 백미밥
# 닭개장
# 돈육바삭불고기
# 우동야채볶음
# 볶음김치/온두부
# 콩나물무침
# 석박지

# %%
# !pip install -q -U google-genai

# %%
# 챗봇 만들
# 구글 제미나이 AI

from google import genai

client = genai.Client(api_key="AIzaSyBktC1SriKoher9ym7lBGxMQdI2bPSEV_M") # GEMINI_API_KEY

response = client.models.generate_content(
    model="gemini-2.5-flash-lite", contents="낮과 밤중 언제가 길어?"
)
print(response.text)
# Out:
# 지구는 자전축이 기울어진 채 태양 주위를 공전하기 때문에 낮과 밤의 길이가 계속 변합니다.
#
# **일반적으로 말하면, 낮과 밤의 길이가 같은 날은 1년에 두 번, 즉 춘분과 추분입니다.**
#
# 하지만 **그 외의 날에는 낮이나 밤 중 어느 한쪽이 더 깁니다.**
#
# *   **여름철:** 북반구에서는 낮이 길고 밤이 짧습니다.
# *   **겨울철:** 북반구에서는 밤이 길고 낮이 짧습니다.
#
# 반대로 남반구에서는 계절이 반대이므로, 북반구가 여름일 때 남반구는 겨울이고, 북반구가 겨울일 때 남반구는 여름입니다.
#
# 따라서 **"언제가 길어?"** 라는 질문에 대한 답은 **"언제냐에 따라 다르다"** 입니다.
