# %% [markdown]
# # 함수

# %% [markdown]
# ## 함수 기본
#
# ![image.png](attachment:689c9f47-811c-4a6e-ad40-dd0d8343a13b.png)

# %%
def add():
    print("더했습니다.") # 보여주는 행위

# %%
def add2():
    return "더했어요." # 손에 쥐어주거나, 돌려주는 행위

# %%
print(add())

# %%
st = add() # 값이 아니라 보여주는 것.
print(st)

# %%
st = add2() # 값 그자체
print(st)

# %% [markdown]
# ---

# %%
# 매개변수
def add(a, b):
    return(a + b)

# %%
add(10, 20) * 10
# Out:
# 300

# %% [markdown]
# ![image.png](attachment:c6e4177a-7329-49da-bf1f-369363676c6d.png)
#
# print는 값을 보여주기에 계산 안 됨

# %% [markdown]
# ---

# %% [markdown]
# ### return의 특징, 함수종료
#
# 리턴 값은 오직 하나, 여러 개일 수 없음

# %%
def return_test():
    '''
    이것은 리턴을 테스트하는 함수입니다.
    '''
    print("리턴 전 입니다.")
    return
    print("리턴 후 입니다.") # return 밑으로는 실행 안됨.
return_test()
# Out:
# 리턴 전 입니다.

# %%
print(return_test.__doc__)
# Out:
#     이것은 리턴을 테스트하는 함수입니다.

# %%
def tt():
    for n in range(10):
        print(n, end="  ")
        if n == 6: return # 6일 때, def 함수가 끝남.

# %% [markdown]
# ---

# %%
# 매개변수 호출
def intro(name):
    print(f"{name}님 안녕하세요.")

# %%
# 재사용성
intro("홍길동")
intro("슈퍼맨")
intro("이순신")
# Out:
# 홍길동님 안녕하세요.
# 슈퍼맨님 안녕하세요.
# 이순신님 안녕하세요.

# %% [markdown]
# ---

# %%
# 실제 연산
def add(a, b):
    c = a + b
    # print(c)
    return c

def mul(a, b):
    c = a * b
    return c

# %% [markdown]
# - 매개변수에 입력 받을 인자의 값이 모자랄 때
#
# add(10)
#
# ![image.png](attachment:fd4ce767-27ec-4922-9e04-025f82b87221.png)

# %%
result = add(30, 20) + mul(30, 20)
print(result)
# Out:
# 650

# %% [markdown]
# ---

# %% [markdown]
# ## 여러 개의 입력값을 받는 함수 만들기

# %%
def add_many(*args):
    result = 0
    for i in args: # 순회 가능/ 리스트, 튜플, 배열 등으로 들어감.
        result += i
    return result

# %%
add_many(11, 22, 33)

# %%
---

# %%
def add_mul(choice, *args):
    if choice == "add":
        result = 0
        for i in args:
            result = result + i
    elif choice == "mul":
        result = 1
        for i in args:
            result == result * i
    return result

# %%
result = add_mul('add', 1,2,3,4,5)
print(result)

result = add_mul('mul', 1,2,3,4,5)
print(result)

# %%
# 해결하기...
def add_mul(choice, *args):
    if choice == "add":
        result = 0
        for i in args:
            result = result + i
    elif choice == "mul":
        result = 1
        for i in args:
            result == result * i
    return result

# %%
result = add_mul('add',1,2,3,4,5)
print(result)

result = add_mul('mul', 1,2,3,4,5)
print(result)

# %%
def print_test(*args):
    print(args,type(args))
print_test(1,2,3,4,5)

# %% [markdown]
# ## 키워드 매개변수, kwargs

# %%
def print_kwargs(**kwargs):
    print(kwargs,type(kwargs))
print_kwargs(name = 'foo', age=3)

# %% [markdown]
# ## 함수의 반환값은 언제나 하나이다. *

# %%
def add_and_mul(a,b):
    # return a+b, a*b
    # return [a+b, a*b]
    return {a+b, a*b}

# %%
value = add_and_mul(3,5)
print(value, type(value))

# %% [markdown]
# ## 매개변수에 초깃값 미리 설정하기 *

# %%
def say_myself(name, age, man=True): # 초기화하고 싶은 매개변수는 항상 뒤쪽에 놓아야 한다는 것을 잊지 말자.
    print("나의 이름은 %s 입니다." % name) 
    print("나이는 %d살입니다." % age) 
    if man: 
        print("남자입니다.")
    else: 
        print("여자입니다.")

say_myself("홍길동", 22)
say_myself("박서방", 23, man = True)
say_myself("향단이", 24, man = False)

# %% [markdown]
# - 초기화하고 싶은 매개변수는 항상 뒤쪽에 놓아야 한다는 것을 잊지 말자.
#
# ![image.png](attachment:496efe7e-cefb-4e05-b9c0-423b1e4f2c94.png)

# %% [markdown]
# ## 함수 안에서 선언한 변수의 효력 범위 *

# %%
# 함수 안에서 사요하는 매개변수는 함수 밖의 변수 이름과는 전혀 상관없다.
a = 1
def vartest(a):
    a = a + 1
vartest(a)
print(a)

# %%
# return 사용하기
a = 1
def vartest(a):
    a = a + 1
    return a
    
a = vartest(a)
print(a)

# %%
# global 사용하기
통장 = 1
def 치트():
    global 통장
    통장 = 통장 + 1
    
print(통장)
치트()
print(통장)

# %%
# 리스트나 딕셔너리는 함수에서 변경 가능하다
box = []
name = "홍길동"

def tt(name):
    box.append(name)
tt('슈퍼맨')

print(box)

# %% [markdown]
# ## lambda 예약어 *
# 자바에서는 익명함수를 뜻함

# %%
add = lambda a, b: a+b
result = add(11,22)
print(result)

# %%
# 한줄짜리 익명함수
print(((lambd x: x**3)(e)0)

# %%
# 응용
students = [("철수", 90), ("영희", 85), ("민수", 95)]
ss = sorted(students, key= lambda x: x[1], reverse = True)

print(ss)

# %%
# json 파싱하여 Lambda로 키를 설정하여 정렬하기
import random as ran

import requests as req
url = "https://jsonplaceholder.typicode.com/todos"
result = req.get(url).json()

print("문제1) id의 번호를 기준으로 내림차순으로 정렬하라.")
fin = sorted(result, key=lambda x : x['id'], reverse= True)
print(fin)

print("문제2) completed 가 True 된 내용만 전처리하라.")
print([n for n in fin if n['completed']== True]) # n은 하나의 딕셔녀리 ㅠㅠ

print("문제3) 리스트에 각 요소 끝에 score 이름으로 키를 만들고 그 키의 값을 40~100까지의 값을 임으로 배정하여 fix하는 변수로 등록하라")
for score in result:
    score['score'] = ran.randint(40,100)
print(result)

print("="*10)

# %%
import requests as req
url = "https://finance.naver.com/sise/sise_market_sum.naver"
ori = req.get(url).text

code = ['005930','000270','005380','012450','068270']

def finance(code = '005930'):
    start_title = ori.find(f'<a href="/item/main.naver?code={code}" class="tltle">')
    ori1 = ori[start_title : start_title + 70].replace(f'<a href="/item/main.naver?code={code}" class="tltle">','').replace('</a></td>','').replace('</a></td','').replace('\n','').strip()
    ori2 = ori[start_title + 70 : start_title + 105].replace('<td class="number">','').replace('</td>','').replace('>','').strip()
    print("종목:",ori1)
    print("가격:",ori2)

for x in code:
    finance(x)
# Out:
# 종목: 삼성전자
# 가격: 178,100
# 종목: 기아
# 가격: 164,900
# 종목: 현대차
# 가격: 505,000
# 종목: 한화에어로스페이스
# 가격: 1,126,000
# 종목: 셀트리온
# 가격: 238,500
