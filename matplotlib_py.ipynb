# %%
# !pip install -r requirements.txt

# %%
# !pip list

# %%
import matplotlib.pyplot as plt
plt.rc('font', family='NanumBarunGotic')

# %%
plt.text(0.5,0.5,"한글")
# Out:
# Text(0.5, 0.5, '한글')
# findfont: Font family 'NanumBarunGotic' not found.
# findfont: Font family 'NanumBarunGotic' not found.
# findfont: Font family 'NanumBarunGotic' not found.
# findfont: Font family 'NanumBarunGotic' not found.
# findfont: Font family 'NanumBarunGotic' not found.
# findfont: Font family 'NanumBarunGotic' not found.
# findfont: Font family 'NanumBarunGotic' not found.
# findfont: Font family 'NanumBarunGotic' not found.
# findfont: Font family 'NanumBarunGotic' not found.
# findfont: Font family 'NanumBarunGotic' not found.
# findfont: Font family 'NanumBarunGotic' not found.
# findfont: Font family 'NanumBarunGotic' not found.
# findfont: Font family 'NanumBarunGotic' not found.
# findfont: Font family 'NanumBarunGotic' not found.
# findfont: Font family 'NanumBarunGotic' not found.
# findfont: Font family 'NanumBarunGotic' not found.
# findfont: Font family 'NanumBarunGotic' not found.
# findfont: Font family 'NanumBarunGotic' not found.
# ...
